# %% [markdown]
# <a href="https://colab.research.google.com/github/dylanguei/pythonhw/blob/main/plot%E7%95%AB%E5%9C%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt


x=[1,2,3,4,5]


plt.plot(x)

# %%
yy=[]
for z in x:
  yy.append(z*z)


yy

[1, 4, 9, 16, 25]

y=[i*i for i in x]


y

[1, 4, 9, 16, 25]

plt.plot(y)

# %%
plt.plot(x,y)

# %%
plt.plot([0.1, 0.2, 0.3, 0.4], [1, 2, 3, 4],
[0.1, 0.2, 0.3, 0.4], [1, 4, 9, 16])
